# %% [markdown]
# <a href="https://colab.research.google.com/github/Jkhou1000/Project_repository/blob/main/Pizza_Graph_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pizzaname = "/content/drive/MyDrive/Coding Dojo/Practice Assignments/PizzaWeek.xlsx"
pizza = pd.read_excel(pizzaname)
pizza.head()
# Out:
#      Topping  Total  Male  Female
# 0  Mushrooms     65    63      68
# 1      Onion     62    62      63
# 2        Ham     61    66      56
# 3    Peppers     60    63      57
# 4    Chicken     56    60      52

# %%
pizza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Topping  19 non-null     object
#  1   Total    19 non-null     int64
#  2   Male     19 non-null     int64
#  3   Female   19 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 736.0+ bytes

# %%
pizza.shape
# Out:
# (19, 4)

# %%
# Out:
# 0          Mushrooms
# 1              Onion
# 2                Ham
# 3            Peppers
# 4            Chicken
# 5          Pepperoni
# 6             Tomato
# 7              Bacon
# 8          Pineapple
# 9          Sweetcorn
# 10              Beef
# 11            Olives
# 12          Chillies
# 13         Jalapenos
# 14           Spinach
# 15              Pork
# 16              Tuna
# 17         Anchovies
# 18    Something else
# Name: Topping, dtype: object

# %%
plt.style.use("classic")
sns.barplot(data=pizza, x="Topping", y='Total')
plt.tick_params(axis='x', rotation=90)
plt.grid(c='g')
plt.title("Total number of people's pizza preferences for toppings!")
# Out:
# No handles with labels found to put in legend.
